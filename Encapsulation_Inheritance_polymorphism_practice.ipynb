# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshKumarBaitha320/Python_with_Data_Science/blob/main/Encapsulation_Inheritance_polymorphism_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TypeError: Student.__init__() takes 2 positional arguments but 3 were given
class Student:
    def __init__(self, name):
        self.name = name

s = Student("Ram", 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1075193939.py in <cell line: 0>()
#       4         self.name = name
#       5
# ----> 6 s = Student("Ram", 20)
#
# TypeError: Student.__init__() takes 2 positional arguments but 3 were given

# %%
# TypeError: Book.__init__() missing 1 required positional argument: 'price'
class Book:
    def __init__(self, title, price):
        self.title = title
        self.price = price

b = Book("Python")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3837136317.py in <cell line: 0>()
#       4         self.price = price
#       5
# ----> 6 b = Book("Python")
#
# TypeError: Book.__init__() missing 1 required positional argument: 'price'

# %%
# TypeError: Car.__init__() takes 1 positional argument but 2 were given
class Car:
    def __init__(self):
        print("Car created")

c = Car(2025)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-319790988.py in <cell line: 0>()
#       3         print("Car created")
#       4
# ----> 5 c = Car(2025)
#
# TypeError: Car.__init__() takes 1 positional argument but 2 were given

# %%
# TypeError: Manager.__init__() takes 2 positional arguments but 3 were given
class Employee:
    def __init__(self, salary):
        self.salary = salary

class Manager(Employee):
    def __init__(self, bonus):
        self.bonus = bonus

m = Manager(50000, 10000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-588561386.py in <cell line: 0>()
#       8         self.bonus = bonus
#       9
# ---> 10 m = Manager(50000, 10000)
#
# TypeError: Manager.__init__() takes 2 positional arguments but 3 were given

# %%
# TypeError: Student.__init__() takes 2 positional arguments but 3 were given
class Person:
    def __init__(self, name):
        self.name = name

class Student(Person):
    def __init__(self, roll):
        self.roll = roll

s = Student("Hari", 12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1772867031.py in <cell line: 0>()
#       8         self.roll = roll
#       9
# ---> 10 s = Student("Hari", 12)
#
# TypeError: Student.__init__() takes 2 positional arguments but 3 were given

# %%
#
class A:
    def __init__(self, x):
        self.x = x

class B(A):
    def __init__(self, x, y):
        self.y = y

b = B(10, 20)

# %%
# AttributeError: 'Account' object has no attribute '__balance'
class Bank:
    def __init__(self, balance):
        self.__balance = balance

class Account(Bank):
    def __init__(self, balance, interest):
        self.__balance = balance
        self.interest = interest

a = Account(10000, 5)
print(a.__balance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1461326897.py in <cell line: 0>()
#       9
#      10 a = Account(10000, 5)
# ---> 11 print(a.__balance)
#
# AttributeError: 'Account' object has no attribute '__balance'
