# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshKumarBaitha320/Python_with_Data_Science/blob/main/TechAxis_Assignment_day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.Write a program that takes a user's name and age as input and prints a personalized message using an f-string.
age=int(input("Enter your age:"))
name=input("Enter your name")
print(f"Hello! I am {name} and i am {age} years old")
# Out:
# Enter your age:22
# Enter your nameRitesh Kumar
# Hello! I am Ritesh Kumar and i am 22 years old

# %%
#2.Write a program that takes the radius of a circle as input and calculates its area. Print the result using an f-string. "The area of circle is ..."
radius=float(input("Enter the radius of circle:"))
area=3.14*radius**2
print(f"The area of circle is:{area:.3f}")
# Out:
# Enter the radius of circle:2.3
# The area of circle is:16.611

# %%
#3.Create a program that prompts the user for their birth year and calculates their age. Display the result using an f-string.
birth_year=int(input("Enter your birth year:"))
current_year=int(input("Enter the current year:"))
age=current_year-birth_year
print(f"My Birth year is {birth_year} and now i am {age} years old ")
# Out:
# Enter your birth year:2003
# Enter the current year:2025
# My Birth year is 2003 and now i am 22 years old

# %%
#4.Write a program that asks the user for their name and greets them with a personalized message using an f-string.
name=input("Enter your name:")
print(f"Hello, {name}! Welcome to the Data Science Faculty")
# Out:
# Enter your name:Ritesh Kumar
# Hello, Ritesh Kumar! Welcome to the Data Science Faculty

# %%
#5.Create a program that requests the user's first and last names separately. Then, it combines the names using an f-string and displays the full name
f_name=input("Enter your first name:")
m_name=input("Enter your middle name:")
l_name=input("Enter your last name:")
print(f"{f_name + m_name + l_name}")
# Out:
# Enter your first name:ritesh
# Enter your middle name:kumar
# Enter your last name:baitha
# riteshkumarbaitha
