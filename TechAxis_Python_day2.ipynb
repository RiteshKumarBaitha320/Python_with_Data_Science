# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshKumarBaitha320/Python_with_Data_Science/blob/main/TechAxis_Python_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# String Concatenation
x="Ritesh"
y="Kumar"
print(x+y)
# Out:
# RiteshKumar

# %%
#String Repetition
a="Pokhara"
print(a*5)
# Out:
# PokharaPokharaPokharaPokharaPokhara

# %%
#String Membership
b="Pokhara"
print("Pokhara" in b)
# Out:
# True

# %%
a="PoKhara"
print("pokhara" in a)
# Out:
# False

# %%
a="Python"
print("on" not in a)
# Out:
# False

# %%
print("y" in a)
print("Y" in a)
# Out:
# True
# False

# %%
sentence="I love Python"
print("python" in sentence)
print("Python" in sentence)
# Out:
# False
# True

# %%
#String Iteration
c="Pokhara"
for i in c:
    print(i)
# Out:
# P
# o
# k
# h
# a
# r
# a

# %%
word="Kathmandu"
for i in word:
    print("\t",i)
# Out:
# 	 K
# 	 a
# 	 t
# 	 h
# 	 m
# 	 a
# 	 n
# 	 d
# 	 u

# %%
#String Formatting with f string
name="Ritesh"
age=21
print(f"My name is {name} and my age is {age}")
# Out:
# My name is Ritesh and my age is 21

# %%
a=22
b=3
div=a/b
print("Div="f"{div:.3f}")
# Out:
# Div=7.333

# %%
name="ram"
age=20
print(f"Hi I am {name} and i am {age+2} years old after 2 years ")
# Out:
# Hi I am ram and i am 22 years old after 2 years

# %%
#Input Function
print("Enter your name:")
name=str(input())
print("My name is",name)
# Out:
# Enter your name:
# ritesh
# My name is ritesh

# %%
name=input("Enter your name:")
print("My name is",name)
# Out:
# Enter your name:ritesh
# My name is ritesh

# %%
print("Enter first Number")
a=int(input())
print("Enter second Number")
b=int(input())
print("Sum=",a+b,f"\tDiv={a/b:0.3f}")
# Out:
# Enter first Number
# 22
# Enter second Number
# 3
# Sum= 25 	Div=7.333

# %%
age=int(input("Enter your age"))
name=input("Enter your name")
print(f"My name is {name} and my age is {age}")
# Out:
# Enter your age22
# Enter your nameritesh
# My name is ritesh and my age is 22
