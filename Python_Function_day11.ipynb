# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshKumarBaitha320/Python_with_Data_Science/blob/main/Python_Function_day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Functions
# Syntax for functions

# def function_name():
  # code

# %%
def greet():
  print("Hello")
  print("Good morning")
greet()
# Out:
# Hello
# Good morning

# %%
greet()
# Out:
# Hello
# Good morning

# %%
def make_tea():
  print("Boiling water")
  print("Adding tea leaves")
  print("Adding sugar")
  print("Adding milk")
  print("Adding lemon")
  print("tea is ready")

make_tea()
# Out:
# Boiling water
# Adding tea leaves
# Adding sugar
# Adding milk
# Adding lemon
# tea is ready
