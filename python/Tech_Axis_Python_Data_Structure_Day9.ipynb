# %%
#tuple:it collection which order of unchangable
# Tuple is a collections which is order and unchangable
# unlike lists they are immutable

# %%
a=(1,2,3,4,5)
type(a)
# Out:
# tuple

# %%
a
# Out:
# (1, 2, 3, 4, 5)

# %%
# Directories:Lots of file
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
# length
len(a) #count
# Out:
# 5

# %%
a[2] #index
# Out:
# 3

# %%
del a[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1251506871.py in <cell line: 0>()
# ----> 1 del a[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
a[2]="ball"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2306985100.py in <cell line: 0>()
# ----> 1 a[2]="ball"
#
# TypeError: 'tuple' object does not support item assignment

# %%
b=([1,2,2,3,"python"],1)
type(b)
# Out:
# tuple

# %%
# Set
a=(2)
type(a)
# Out:
# int

# %%
t=(1,2,[3,4],5)
t[2][0]
# Out:
# 3

# %%
# sets
# sets is a built in data structure that represents the oredered collection of unique elements
a={1,2,3,3,4,5,6}
a
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
type(a)
# Out:
# set

# %%
a={2,1,3,2,7,4,5}
a
# Out:
# {1, 2, 3, 4, 5, 7}

# %%
a={1,"a"}
a
# Out:
# {1, 'a'}

# %%
a={1,6,5,"ritesh",2,3}
a
# Out:
# {1, 2, 3, 5, 6, 'ritesh'}

# %%
set1={1,2,3}
set2={3,4,5}
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
union_set=set1.union(set2)
intersetcion_set=set1.intersection(set2)

print(f"Union of set{union_set}")
print(f"Intersection operation of set:{intersetcion_set}")
# Out:
# Union of set{1, 2, 3, 4, 5}
# Intersection operation of set:{3}
