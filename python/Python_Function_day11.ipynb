# %%
# Functions
# Syntax for functions

# def function_name():
  # code

# %%
def greet():
  print("Hello")
  print("Good morning")
greet()
# Out:
# Hello
# Good morning

# %%
greet()
# Out:
# Hello
# Good morning

# %%
def make_tea():
  print("Boiling water")
  print("Adding tea leaves")
  print("Adding sugar")
  print("Adding milk")
  print("Adding lemon")
  print("tea is ready")

make_tea()
# Out:
# Boiling water
# Adding tea leaves
# Adding sugar
# Adding milk
# Adding lemon
# tea is ready
